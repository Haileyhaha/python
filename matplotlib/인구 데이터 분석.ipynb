import csv
# UTF-8 인코딩 설정
x1 = []
x2 = []
name = input('인구구조의 변화가 궁금한 지역을 입력해주세요 : ')

with open("age2022.csv", mode='r', encoding='utf-8') as file1:
    data1 = csv.reader(file1)
    next(data1)
    for row in data1:
        if name in row[0]:
            # print(row)
            for i in range(3,104):
                x1.append(int(row[i]))
                # print(row[i])
            break
print(x1)
with open("age2012.csv", mode='r', encoding='utf-8') as file2:
    data2 = csv.reader(file2)
    next(data2)
    for row in data2:
        if name in row[0]:
            # print(row)
            for i in range(3,104):
                x2.append(int(row[i]))
                # print(row[i])
            break
print(x2)

import matplotlib.pyplot as plt
plt.title(name + ' 지역의 인구구조 변화')
plt.plot(x1 , c = 'blue', label ='2022')
plt.plot(x2 , c = 'red', label = '2012')
plt.legend()
plt.show()
# Out:
# 인구구조의 변화가 궁금한 지역을 입력해주세요 :  마북동
# [134, 195, 202, 207, 218, 245, 271, 280, 293, 306, 324, 311, 299, 287, 309, 307, 290, 302, 305, 326, 324, 357, 433, 387, 451, 410, 430, 458, 392, 405, 391, 338, 356, 388, 337, 320, 372, 366, 448, 508, 531, 556, 534, 460, 487, 448, 511, 502, 602, 614, 575, 651, 584, 552, 529, 498, 490, 486, 443, 454, 435, 470, 401, 405, 364, 352, 381, 375, 343, 319, 291, 288, 301, 299, 316, 296, 257, 246, 247, 287, 244, 187, 175, 147, 151, 121, 96, 78, 81, 58, 45, 44, 28, 28, 18, 18, 7, 2, 1, 2, 12]
# [318, 345, 346, 338, 383, 373, 330, 340, 353, 355, 379, 381, 450, 420, 462, 437, 411, 431, 404, 445, 370, 329, 303, 284, 264, 254, 294, 302, 332, 424, 482, 516, 559, 539, 515, 546, 552, 590, 631, 677, 616, 700, 631, 605, 584, 546, 522, 531, 444, 457, 419, 437, 394, 349, 367, 326, 372, 400, 320, 312, 325, 279, 283, 308, 323, 355, 281, 258, 274, 301, 306, 262, 211, 176, 173, 140, 133, 134, 118, 85, 92, 71, 76, 49, 52, 38, 40, 15, 15, 24, 23, 23, 11, 16, 8, 8, 6, 1, 0, 1, 1]

# %%
# 제주도는 정말 삼다도 일까요 ?
m = [] #남성
f = [] #여성

with open("age_gender.csv", mode='r', encoding='utf-8') as file3:
    data3 = csv.reader(file3)
    next(data3)
    for row in data3:
        if '제주특별자치도' in row[0]:
            for i in range(3,104):
                m.append(-int(row[i]))
                f.append(int(row[i+103]))
            break
print(m) 
print(f)
# Out:
# [-1833, -2082, -2264, -2580, -2786, -3119, -3580, -3543, -3612, -3772, -3972, -3947, -3684, -3612, -3752, -3671, -3457, -3450, -3692, -3491, -3846, -4230, -4364, -3988, -4102, -4257, -4320, -4225, -4420, -4380, -4165, -3824, -3725, -3520, -3518, -3680, -4002, -4133, -4517, -5256, -5657, -5774, -5820, -5110, -5107, -5462, -5411, -6011, -6334, -6408, -6584, -6760, -6382, -6580, -5978, -5633, -6049, -5407, -5247, -5898, -5205, -5555, -5129, -4801, -4539, -4121, -3915, -3988, -2769, -2765, -2674, -2418, -2195, -2498, -2367, -2243, -1769, -1775, -1614, -1666, -1589, -1306, -1176, -1079, -932, -756, -665, -574, -449, -327, -236, -173, -125, -85, -29, -31, -14, -11, -8, -14, -10]
# [1705, 1917, 2165, 2438, 2662, 2894, 3255, 3460, 3453, 3649, 3703, 3734, 3329, 3420, 3597, 3336, 3074, 3103, 3250, 3184, 3079, 3768, 3744, 3584, 3682, 3701, 3874, 3862, 3925, 4094, 3900, 3596, 3565, 3514, 3478, 3703, 3924, 4149, 4654, 5384, 5611, 5648, 5805, 5128, 5023, 4965, 5024, 5266, 5983, 6111, 6250, 6160, 5962, 6076, 5453, 5064, 5477, 5133, 4974, 5415, 5114, 5507, 5131, 4760, 4433, 4227, 4076, 4231, 2970, 2991, 2829, 2684, 2660, 2712, 2719, 2718, 2113, 2218, 2224, 2265, 2324, 2023, 1999, 1925, 1662, 1594, 1496, 1331, 1262, 1092, 907, 648, 605, 416, 327, 202, 148, 108, 113, 190, 198]

# %%
# 시각화 하기
import matplotlib.pyplot as plt
plt.barh(range(101),m)
plt.barh(range(101),f)
plt.show()

# %%
# 제주도는 정말 삼다도 일까요 ?
m = 0 #남성
f = 0 #여성

with open("age_gender.csv", mode='r', encoding='utf-8') as file3:
    data3 = csv.reader(file3)
    next(data3)
    for row in data3:
        if '제주특별자치도' in row[0]:
            for i in range(3,104):
                m = m + int(row[i])
                f = f + int(row[i+103])
            break
print(m) 
print(f)
# Out:
# 339578
# 338188

# %%
# 제주도는 정말 삼다도 일까요 ?
c = []
with open("age_gender2008.csv", mode='r', encoding='utf-8') as file3:
    data3 = csv.reader(file3)
    next(data3)
    for row in data3:
        if '제주특별자치도' in row[0]:
            for i in range(3,104):
                c.append(int(row[i+103]) -int(row[i])) 
            break
print(c)

import matplotlib.pyplot as plt
plt.bar(range(101),c)
plt.show()
# Out:
# [-177, -230, -311, -341, -457, -302, -542, -205, -467, -235, -400, -491, -511, -384, -486, -434, -395, -439, -441, -285, -311, -318, -409, -340, -212, -327, -233, -166, -87, 22, -196, -385, -185, -340, -137, -77, -103, -327, -273, -405, -439, -554, -694, -302, -438, -608, -323, -176, -205, -274, -314, -295, -64, 84, -66, 15, -78, -65, 192, -39, -11, 130, 68, 134, 238, 238, 311, 433, 505, 468, 506, 735, 762, 722, 863, 964, 965, 822, 1028, 779, 842, 607, 518, 371, 520, 1060, 634, 445, 367, 303, 283, 288, 192, 169, 152, 114, 68, 80, 46, 32, 56]

# %%
# 우리동네와 인구구조가 가장 비슷한 지역은 어딜까요 ? 
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

plt.title('신도림동과 화천면의 인구비교')

result1=[]
result2=[]
data= csv.reader(open('./age.csv'))

for row in data :
    if '신도림동' in row[0] : 
        for i in range(3, 104) :
            result1.append(int(row[i]))
    if '화촌면' in row[0] : 
        for i in range(3, 104) :
            result2.append(int(row[i]))
            
plt.plot(result1)
plt.plot(result2)
plt.show()

# %%
# 우리동네와 인구구조가 가장 비슷한 지역은 어딜까요 ? 
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

plt.title('신도림동과 화천면의 인구 비율')

result1=[]
result2=[]
data= csv.reader(open('age.csv'))

for row in data :
    if '신도림동' in row[0] : 
        for i in range(3, 104) :
            result1.append(int(row[i])/int(row[2]))
    if '화촌면' in row[0] : 
        for i in range(3, 104) :
            result2.append(int(row[i])/int(row[2]))
            
plt.plot(result1)
plt.plot(result2)
plt.show()

# %% [markdown]
# $$ s = \sum (기준지역의 해당 연령값 - 각지역의 해당 연령값)^{2} $$

# %%
# 인구구조가 가장 비슷하다는 것은?

import csv

pivot =[]
data= csv.reader(open('age.csv'))
next(data)
next(data)
data = list(data)

name = input('궁금한 지역 이름을 입력해주세요 :  ')

for row in data :
    if name in row[0] : 
        for i in range(3, len(row)) :
          pivot.append(int(row[i]) / int(row[2]))
        break
mn= 10000
print(pivot)
for row in data:
    s = 0
    # 16 ~ 20 오차 계산
    for i in range(3, len(row)):
        row[i] = int(row[i])/int(row[2]) #비율로 바꿔주는 코드
        tmp = (row[i]-pivot[i-3]) **2 # 두값의 차이를 제곱 
        s = s+tmp #차이의 제곱을 누적해서더하기
    # 22 ~ 26 : 역대 최소 오차를 업데이트
    if s < mn and (name not in row[0]):
        result = []
        for i in range(3, len(row)):
            result.append(row[i])
        mn = s
        result_name = row[0]
plt.figure(dpi =300)
plt.style.use('ggplot')

plt.plot(pivot, label = name)
plt.plot(result, label = result_name)
plt.legend()
plt.show()
# Out:
# 궁금한 지역 이름을 입력해주세요 :   금곡동
# [0.0035850438031760456, 0.0041909666994874905, 0.0054533060668029995, 0.00547855285414931, 0.005756267514958721, 0.006235956474538615, 0.006614658284733268, 0.005882501451690272, 0.007473049054507814, 0.007094347244313161, 0.0064884243480017164, 0.007271074755737333, 0.007801257290009847, 0.007245827968391023, 0.007346815117776263, 0.007927491226741397, 0.008684894847130703, 0.009366558105481078, 0.010628897472796587, 0.011840743265419475, 0.010654144260142898, 0.012547653311116161, 0.012345679012345678, 0.012699134035194022, 0.011689262541341615, 0.011891236840112096, 0.012774874397232952, 0.013229316569466536, 0.011689262541341615, 0.010628897472796587, 0.010502663536065035, 0.009265570956095837, 0.009492792042212629, 0.008836375571208564, 0.009013103082632735, 0.008710141634477012, 0.009492792042212629, 0.01108333964503017, 0.011638768966648994, 0.012875861546618192, 0.012269938650306749, 0.012093211138882577, 0.010275442449948245, 0.011032846070337549, 0.012345679012345678, 0.014643136660859906, 0.014769370597591456, 0.0166123860738721, 0.016284177838370068, 0.018354414400767502, 0.017899972228533918, 0.018707869423615846, 0.01837966118811381, 0.018354414400767502, 0.0190865712338105, 0.01951576661869777, 0.017773738291802368, 0.021409275669671036, 0.021485016031709964, 0.023328031507990607, 0.02234340680148451, 0.0205761316872428, 0.01815244010199702, 0.01931379231992729, 0.015577267792673382, 0.017319296119568783, 0.013103082632734984, 0.012800121184579263, 0.01242141937438461, 0.010073468151177763, 0.01105809285768386, 0.010351182811987174, 0.009467545254866318, 0.009972481001792521, 0.00696811330758161, 0.00825569946224343, 0.007548789416546744, 0.00987149385240728, 0.0081799591002045, 0.008205205887550809, 0.00689237294554268, 0.007069100456966851, 0.005125097831300967, 0.005756267514958721, 0.004998863894569416, 0.004796889595798935, 0.003181095205635083, 0.0031306016309424626, 0.00275189982074781, 0.0017420283268954025, 0.0011613522179302683, 0.0012118457926228888, 0.0009341311318134767, 0.0005301825342725138, 0.00032820823550203234, 0.000277714660809412, 0.00020197429877048145, 5.049357469262036e-05, 0.0001514807240778611, 0.0, 0.00010098714938524072]
