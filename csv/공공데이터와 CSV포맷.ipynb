# %%
## 1) 파일 읽어오기
filename = open('우리반명단.txt')

# %%
## 2) 반복문으로 파일에서 한줄씩 읽어오기
# 파일을 UTF-8로 읽어오기
with open("우리반명단.txt", mode='r', encoding='utf-8') as file:
    for row in file:
        print(row)
# Out:
# ﻿마동석
#
# 류승룡
#
# 유해진
#
# 고아성
#
# 이정재
#
# 하지원
#
# 송강호
#
# 이경영
#
# 배두나
#
# 이정은
#
# 하정우
#
# 송중기
#
# 설경구
#
# 최민식
#
# 라미란
#
# 송혜교
#
# 전지현
#
# 황정민
#
# 김혜수
#
# 박소담

# %%
data = open("우리반명단.txt", mode='r', encoding='utf-8')
print(data)
# Out:
# <_io.TextIOWrapper name='우리반명단.txt' mode='r' encoding='utf-8'>

# %%
# 1. 우리반 명단을 리스트에 저장
names =[]
for row in data:
    names.append(row)
print(names)
# Out:
# ['\ufeff마동석\n', '류승룡\n', '유해진\n', '고아성\n', '이정재\n', '하지원\n', '송강호\n', '이경영\n', '배두나\n', '이정은\n', '하정우\n', '송중기\n', '설경구\n', '최민식\n', '라미란\n', '송혜교\n', '전지현\n', '황정민\n', '김혜수\n', '박소담']

# %%
# 2. 랜덤하게 불러오기 
import random
print(random.choice(names))
# Out:
# 라미란

# %%
# 3.오늘의 주인공 뽑기
import random, time

data = open("우리반명단.txt", mode='r', encoding='utf-8')
print(data)

names =[]
for row in data:
    names.append(row)
print('오늘의 주인공은 바로 !!!')
time.sleep(3)
print(random.choice(names))
# Out:
# <_io.TextIOWrapper name='우리반명단.txt' mode='r' encoding='utf-8'>
# 오늘의 주인공은 바로 !!!
# ﻿마동석

# %%
# 4. 궁금한 성을 가진 사람만 뽑기
data = open("우리반명단.txt", mode='r', encoding='utf-8')
for row in data:
    if row[0]== '송':
        print(row)
# Out:
# 송강호
#
# 송중기
#
# 송혜교

# %%
# 5. 명단에서 궁금한 성을 가진 사람만 리스트에 추가하기
data = open("우리반명단.txt", mode='r', encoding='utf-8')
x = input('궁금한 성을 입력해주세요: ' )
names=[]
for row in data:
    if row[0]== x:
        names.append(row)
print(names)
# Out:
# 궁금한 성을 입력해주세요:  송
# ['송강호\n', '송중기\n', '송혜교\n']

# %%
# 문자열.strip() : 문자열 좌우에 있는 \n \t등의 특수 문자 제거
t = '\t 안녕하세요 !\n'
print(t)
print(t.strip())
# Out:
# 	 안녕하세요 !
#
# 안녕하세요 !

# %%
data = open("우리반명단.txt", mode='r', encoding='utf-8')
x = input('궁금한 성을 입력해주세요: ' )
names=[]
for row in data:
    if row[0]== x:
        names.append(row.strip())
print(names)
# Out:
# 궁금한 성을 입력해주세요:  송
# ['송강호', '송중기', '송혜교']

# %%
# 공공 데이터 가져와서 처리하기
# csv : comma-separated values 컴마로 구분된 값
import csv
data = csv.reader(open('seoultemp.csv'))
print(data)
# Out:
# <_csv.reader object at 0x00000292D18719C0>

# %%
# 최고 기온 데이터 그래프로 표현해보기

import csv
data = csv.reader(open('seoultemp.csv', encoding='utf-8'))
next(data) 
temp=[]
for row in data:
    if row[-1] != '': #최고 기온이 비어있지 않은 데이터만 출력
        temp.append(float(row[-1]))

import matplotlib.pyplot as plt
plt.plot(temp)
plt.show()
plt.boxplot(temp)
plt.show()
plt.hist(temp, bins=100)
plt.show()

# %%
# 우리지역의 역대 최고 기온은?
import csv
data = csv.reader(open('seoultemp.csv', encoding='utf-8'))
next(data) 
memo = -1000
date = ''
for row in data:
    if row[-1] != '':
        if memo < float(row[-1]):
            memo = float(row[-1])
            date = row[0]
print(date,memo)
# Out:
# 2018.8.1 39.6

# %%
# 지난 100년간, 내 생일의 기온을 그래프로 표현한다면?
#a in b # a가 b에 포함되어있는가?

# %%
print('tho' in 'python')
print('no' in 'python')
# Out:
# True
# False

# %%
# 생일 데이터만 출력
import csv
data = csv.reader(open('seoultemp.csv', encoding='utf-8'))
next(data) 
for row in data:
    if row[-1] != '':
        if '.7.18' in row[0]:
            print(row)
# Out:
# ['1908.7.18', '108', '24.6', '19.5', '31.5']
# ['1909.7.18', '108', '24.2', '23.6', '25.8']
# ['1910.7.18', '108', '22.3', '21.1', '23.8']
# ['1911.7.18', '108', '25.7', '22.5', '31']
# ['1912.7.18', '108', '23.3', '20.8', '26']
# ['1913.7.18', '108', '21.4', '19.6', '23.5']
# ['1914.7.18', '108', '26.4', '23.8', '30.6']
# ['1915.7.18', '108', '25.2', '23.6', '28.5']
# ['1916.7.18', '108', '24.1', '17.5', '30.8']
# ['1917.7.18', '108', '26.2', '21.9', '32.3']
# ['1918.7.18', '108', '23.8', '17.4', '31']
# ['1919.7.18', '108', '27.6', '22.6', '35.3']
# ['1920.7.18', '108', '26.4', '23', '32']
# ['1921.7.18', '108', '24.9', '22.3', '28.4']
# ['1922.7.18', '108', '26.2', '22', '30.5']
# ['1923.7.18', '108', '23.2', '20.8', '26.3']
# ['1924.7.18', '108', '26.7', '23.1', '31.9']
# ['1925.7.18', '108', '24.2', '20.9', '26.4']
# ['1926.7.18', '108', '22.2', '20.5', '24.6']
# ['1927.7.18', '108', '26.4', '23.9', '30.1']
# ['1928.7.18', '108', '27', '21.9', '33.7']
# ['1929.7.18', '108', '26.7', '21.5', '33.2']
# ['1930.7.18', '108', '25.7', '22.4', '29.1']
# ['1931.7.18', '108', '21.7', '20.5', '24']
# ['1932.7.18', '108', '24.5', '23.5', '28.5']
# ['1933.7.18', '108', '27.4', '24.5', '32.2']
# ['1934.7.18', '108', '21.2', '20.1', '24.1']
# ['1935.7.18', '108', '23.3', '20.1', '28.6']
# ['1936.7.18', '108', '23.5', '20.9', '29.2']
# ['1937.7.18', '108', '23.6', '22.3', '25.3']
# ['1938.7.18', '108', '25.5', '22.9', '30.6']
# ['1939.7.18', '108', '28.6', '23.4', '36.1']
# ['1940.7.18', '108', '24.6', '20.3', '30.7']
# ['1941.7.18', '108', '24.7', '19.9', '31.3']
# ['1942.7.18', '108', '26.8', '24.3', '31.1']
# ['1943.7.18', '108', '27', '23.5', '33.4']
# ['1944.7.18', '108', '24.6', '23.2', '28.2']
# ['1945.7.18', '108', '22.9', '19.1', '27.8']
# ['1946.7.18', '108', '27.3', '22.2', '34.5']
# ['1947.7.18', '108', '20.9', '18.4', '25']
# ['1948.7.18', '108', '24.8', '21.5', '29.9']
# ['1949.7.18', '108', '27.6', '24.2', '34']
# ['1950.7.18', '108', '28.7', '24', '33.8']
# ['1954.7.18', '108', '21.1', '19.5', '24.2']
# ['1955.7.18', '108', '26', '23.5', '28.9']
# ['1956.7.18', '108', '22', '21', '23.3']
# ['1957.7.18', '108', '24.7', '21.5', '28.7']
# ['1958.7.18', '108', '26.3', '23', '32.1']
# ['1959.7.18', '108', '22.9', '19.7', '27.4']
# ['1960.7.18', '108', '26.9', '23.7', '31.4']
# ['1961.7.18', '108', '27.8', '22.8', '33.5']
# ['1962.7.18', '108', '24.7', '22.4', '29.3']
# ['1963.7.18', '108', '25.4', '21.2', '30.5']
# ['1964.7.18', '108', '24.1', '20.8', '29']
# ['1965.7.18', '108', '26.2', '21.9', '31.4']
# ['1966.7.18', '108', '24.7', '23.2', '27']
# ['1967.7.18', '108', '28.8', '24.9', '34.7']
# ['1968.7.18', '108', '24.1', '23.1', '25.3']
# ['1969.7.18', '108', '23.9', '21.3', '25.9']
# ['1970.7.18', '108', '21.4', '20.6', '22.2']
# ['1971.7.18', '108', '24.9', '22', '28.8']
# ['1972.7.18', '108', '27.3', '23.1', '33.3']
# ['1973.7.18', '108', '30.6', '26.8', '34.5']
# ['1974.7.18', '108', '25.9', '22.7', '29.8']
# ['1975.7.18', '108', '26.5', '22.4', '30.4']
# ['1976.7.18', '108', '25.5', '21.4', '30.1']
# ['1977.7.18', '108', '25.9', '21.6', '30.4']
# ['1978.7.18', '108', '25.6', '22.9', '29.2']
# ['1979.7.18', '108', '23.4', '17.5', '28.7']
# ['1980.7.18', '108', '21.1', '20', '22.9']
# ['1981.7.18', '108', '27.6', '24.9', '31.6']
# ['1982.7.18', '108', '24.7', '20.3', '29.9']
# ['1983.7.18', '108', '23.2', '20.9', '26.5']
# ['1984.7.18', '108', '25.5', '20.7', '29.9']
# ['1985.7.18', '108', '24.7', '21.9', '28.2']
# ['1986.7.18', '108', '22.9', '19.7', '26']
# ['1987.7.18', '108', '23.7', '20.3', '28.6']
# ['1988.7.18', '108', '24.7', '22.3', '28.3']
# ['1989.7.18', '108', '26.9', '24', '31.3']
# ['1990.7.18', '108', '24', '22.2', '25.3']
# ['1991.7.18', '108', '25.7', '22.6', '30.3']
# ['1992.7.18', '108', '24', '20.9', '28.9']
# ['1993.7.18', '108', '22.3', '17.7', '27.6']
# ['1994.7.18', '108', '30.9', '26.3', '36']
# ['1995.7.18', '108', '23.3', '19.8', '27.3']
# ['1996.7.18', '108', '27.9', '22.5', '33.5']
# ['1997.7.18', '108', '26.1', '22.3', '30.5']
# ['1998.7.18', '108', '25.3', '22.2', '29']
# ['1999.7.18', '108', '25.3', '22.2', '30.3']
# ['2000.7.18', '108', '27.7', '25.1', '32']
# ['2001.7.18', '108', '26.4', '22.3', '31.4']
# ['2002.7.18', '108', '24.9', '20.6', '29.2']
# ['2003.7.18', '108', '19.8', '18.3', '22.4']
# ['2004.7.18', '108', '25.2', '22.1', '28.2']
# ['2005.7.18', '108', '26.4', '23.5', '31.2']
# ['2006.7.18', '108', '19.1', '17.5', '20.7']
# ['2007.7.18', '108', '26', '19.7', '31']
# ['2008.7.18', '108', '26.2', '22.8', '30.1']
# ['2009.7.18', '108', '25.1', '21.1', '27.3']
# ['2010.7.18', '108', '25.9', '23.1', '29.1']
# ['2011.7.18', '108', '28.7', '24.4', '34.1']
# ['2012.7.18', '108', '26.3', '24.7', '28.4']
# ['2013.7.18', '108', '25.1', '23.8', '27.7']
# ['2014.7.18', '108', '26.1', '22.6', '30.6']
# ['2015.7.18', '108', '24.3', '22.3', '27.8']
# ['2016.7.18', '108', '24.4', '20.7', '28.4']
# ['2017.7.18', '108', '26.5', '23.9', '30.7']
# ['2018.7.18', '108', '28.2', '23.7', '33.2']
# ['2019.7.18', '108', '26.9', '23.3', '32.1']
# ['2020.7.18', '108', '26.1', '22.8', '31']

# %%
# 생일데이터만 리스트로 저장
import csv
data = csv.reader(open('seoultemp.csv', encoding='utf-8'))
next(data) 
x = []
for row in data:
    if row[-1] != '':
        if '.7.18' in row[0]:
            x.append(float(row[-1]))
print(x)
# Out:
# [31.5, 25.8, 23.8, 31.0, 26.0, 23.5, 30.6, 28.5, 30.8, 32.3, 31.0, 35.3, 32.0, 28.4, 30.5, 26.3, 31.9, 26.4, 24.6, 30.1, 33.7, 33.2, 29.1, 24.0, 28.5, 32.2, 24.1, 28.6, 29.2, 25.3, 30.6, 36.1, 30.7, 31.3, 31.1, 33.4, 28.2, 27.8, 34.5, 25.0, 29.9, 34.0, 33.8, 24.2, 28.9, 23.3, 28.7, 32.1, 27.4, 31.4, 33.5, 29.3, 30.5, 29.0, 31.4, 27.0, 34.7, 25.3, 25.9, 22.2, 28.8, 33.3, 34.5, 29.8, 30.4, 30.1, 30.4, 29.2, 28.7, 22.9, 31.6, 29.9, 26.5, 29.9, 28.2, 26.0, 28.6, 28.3, 31.3, 25.3, 30.3, 28.9, 27.6, 36.0, 27.3, 33.5, 30.5, 29.0, 30.3, 32.0, 31.4, 29.2, 22.4, 28.2, 31.2, 20.7, 31.0, 30.1, 27.3, 29.1, 34.1, 28.4, 27.7, 30.6, 27.8, 28.4, 30.7, 33.2, 32.1, 31.0]

# %%
# 그래프로 표현하기
import matplotlib.pyplot as plt
plt.plot(x)
plt.show()

plt.boxplot(x)
plt.show()

# %%
# 1년중 일교차가 가장 큰달은 몇월 일까요?
# 월별 기온 분포 확인하기
date = '2000-01-01'
print(date.split('-'))
# Out:
# ['2000', '01', '01']

# %%
import csv
data = csv.reader(open('seoultemp.csv', encoding='utf-8'))
next(data) 
july =[]
august =[]
for row in data:
    if row[-1] != '' and row[-2] !='':
        if row[0].split('.')[1] == '7':
            july.append(float(row[-1])-float(row[-2]))
        if row[0].split('.')[1] == '8':
            august.append(float(row[-1])-float(row[-2]))

import matplotlib.pyplot as plt
plt.boxplot([july, august])
plt.show()

# %%
#1년중 일교차가 가장 큰달은?
import csv
data = csv.reader(open('seoultemp.csv', encoding='utf-8'))
next(data) 
x=[]

for i in range(12):
    x.append([])
print(x)

for row in data:
    if row[-1] != '' and row[-2] != '':
        x[int(row[0].split('.')[1]) - 1].append(float(row[-1])-float(row[-2]))

import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

plt.title('월별 일교차')
plt.boxplot(x)
plt.show()
# Out:
# [[], [], [], [], [], [], [], [], [], [], [], []]

# %%
# 가장 덥고, 가장 추운날?
import csv
data = csv.reader(open('seoultemp.csv', encoding='utf-8'))
next(data)

x=[]
temp =[]

for i in range(31):
    temp.append([])
for row in data:
    if row[-1] != '' :
        if row[0].split('.')[1] == '9' :
            temp[int(row[0].split('.')[2])-1].append(float(row[-1]))

import matplotlib.pyplot as plt
plt.boxplot(temp)
plt.show()
